# %%
import time

import numpy as np
from scipy.special import softmax

import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.data import Dataset
from tensorflow.keras import Model
from tensorflow.keras.layers import Embedding, Conv1D, MaxPool1D, Dropout, Flatten, Dense, Concatenate
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import Accuracy, Mean
from tensorflow.keras.optimizers import Adam
from tensorflow.train import Checkpoint, CheckpointManager

from sklearn.metrics import accuracy_score, f1_score, classification_report

# %% [markdown]
# # Data handler

# %%
aspect2id = {
    'RESTAURANT': 0,
    'FOOD': 1,
    'DRINKS': 2,
    'LOCATION': 3,
    'AMBIENCE': 4,
    'SERVICE': 5,
}

# %%
def get_vocab(file):
    word2id = {}
    r = open(file, 'r', encoding='utf-8')
    count = 1
    for word in r.read().split('\n'):
        word2id[word] = count
        count += 1
    r.close()
    return word2id

word2id = get_vocab('wordset/restaurant_vocab.txt')

# %%
num_aspects = len(aspect2id)
vocab_size = len(word2id)

# %%
def get_seed(file):
    seed_set = {}
    r = open(file, 'r', encoding='utf-8')
    seeds = r.read().split('\n')[0:-1]
    for i in range(len(seeds)):
        seeds[i] = seeds[i].split('|')[:-1]
        seed_tokens = []
        for seed in seeds[i]:
            if seed in word2id:
                seed_tokens.append(word2id[seed])
            else:
                seed_tokens.append(-1)
        seed_set[i] = seed_tokens
    r.close()
    return seed_set

seed_set = get_seed('wordset/restaurant_seeds.txt')

# %%
def get_train_inp(file):
    r = open(file, 'r', encoding='utf-8')
    docs = r.readlines()
    inps = []
    for i in range(len(docs)):
        docs[i] = docs[i].split()
        inp = [word2id[word] for word in docs[i]]
        inps.append(inp)
    r.close()
    return inps

train_inp = get_train_inp('processed/restaurant_train.txt')

# %%
def get_test(file):
    r = open(file, 'r', encoding='utf-8')
    lines = r.readlines()
    inps = []
    outs = []
    for line in lines:
        sent = line.split('|')[0]
        inp = []
        inp = [word2id[word] for word in sent.split() if word in word2id]
        # if len(inp) == 0:
        #     continue
        inps.append(inp)
        
        #print(line)
        aspect = line.split('|')[1][:-1]
        label = aspect2id[aspect]
        out = [0 for i in range(num_aspects)]
        out[label] = 1
        outs.append(out)
    
    r.close()
    return inps, np.array(outs)

dev_inp, dev_out = get_test('processed/restaurant_dev.txt')
test_inp, test_out = get_test('processed/restaurant_test.txt')

# %%
def get_weight_seed(inps, preds, seed_set):
    weight_seed = {}
    for label in seed_set:
        for seed in seed_set[label]:
            weight_seed[seed] = np.zeros(num_aspects)
    
    for i in range(inps.shape[0]):
        for seed in weight_seed:
            if seed in inps[i]:
                weight_seed[seed][preds[i]] += 1

    for label in seed_set:
        for seed in seed_set[label]:
            sum = np.sum(weight_seed[seed])
            if sum != 0:
                weight_seed[seed] /= sum    
    
    return weight_seed

# %%
default_weight_seed = {}

for label in seed_set:
    for seed in seed_set[label]:
        default_weight_seed[seed] = np.ones(num_aspects)
        #default_weight_seed[seed] /= np.sum(default_weight_seed[seed])

# %%
def get_train_weak_out(inps, seed_set, weight_seed=default_weight_seed):
    outs = []
    for inp in inps:
        out = []
        cnt = 0
        for label in seed_set:
            bow = 0
            for seed in seed_set[label]:
                bow += np.count_nonzero(inp == seed) * weight_seed[seed][label]
            if bow == 0:
                cnt += 1
            out.append(bow)
    
        if cnt == len(seed_set):
            out[0] = 10000000
        outs.append(out)
    
    outs = softmax(outs, axis=1)
    return outs

# %% [markdown]
# # Visualize data

# %%
from collections import Counter
import matplotlib.pyplot as plt

# %%
len_train_inp = [len(inp) for inp in train_inp]
len_train_inp = Counter(len_train_inp)
plt.bar(len_train_inp.keys(), len_train_inp.values(), width=1, color='g')
# Out:
# <BarContainer object of 139 artists>

# %%
len_test_inp = [len(inp) for inp in test_inp]
len_test_inp = Counter(len_test_inp)
plt.bar(len_test_inp.keys(), len_test_inp.values(), width=1, color='g')
# Out:
# <BarContainer object of 49 artists>

# %%
test_label = np.argmax(test_out, axis=1)
len_test_label = Counter(test_label)
plt.bar(len_test_label.keys(), len_test_label.values(), width=1, color='g')
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# # Create dataset

# %%
max_len = 30

train_inp = [inp if len(inp) < max_len else inp[0:max_len] for inp in train_inp]
dev_inp = [inp if len(inp) < max_len else inp[0:max_len] for inp in dev_inp]
test_inp = [inp if len(inp) < max_len else inp[0:max_len] for inp in test_inp]

# %%
train_inp = pad_sequences(train_inp, maxlen=max_len)
dev_inp = pad_sequences(dev_inp, maxlen=max_len)
test_inp = pad_sequences(test_inp, maxlen=max_len)

# %% [markdown]
# # Define model

# %%
class CNNModel(Model):
    def __init__(self, vocab_size, max_len, embedding_dim=300, filters=64, \
        kernel_size=[2,3], pool_size=2, dropout_rate=0.5, hidden_dim=100, output_dim=num_aspects):
        super().__init__(self)

        self.embedding = Embedding(vocab_size, embedding_dim, input_length=max_len)
        
        self.conv1 = Conv1D(filters=filters, kernel_size=kernel_size[0], activation='relu')
        self.conv2 = Conv1D(filters=filters, kernel_size=kernel_size[1], activation='relu')
        
        self.dropout = Dropout(dropout_rate)
        self.maxpool = MaxPool1D(pool_size)
        
        self.flat1 = Flatten()
        self.concat = Concatenate()
        self.hidden = Dense(hidden_dim, activation='relu')

        self.dense = Dense(output_dim, activation='softmax')
    
    def call(self, inputs, training):
        x = inputs
        x = self.embedding(x, training=training)

        x1 = self.conv1(x, training=training)
        x1 = self.maxpool(x1)
        x1 = self.flat1(x1)

        x2 = self.conv2(x, training=training)
        x2 = self.maxpool(x2)
        x2 = self.flat1(x2)

        x = self.concat([x1, x2])
        x = self.dropout(x, training=training)

        x = self.hidden(x, training=training)
        x = self.dense(x, training=training)
        return x

# %%
cnn_model = CNNModel(
    vocab_size=vocab_size,
    max_len=max_len)

# %% [markdown]
# # Hyper-parameter

# %%
loss_function = CategoricalCrossentropy()
accuracy_function = Accuracy()

train_loss = Mean(name='train_loss')
dev_loss = Mean(name='dev_loss')
test_loss = Mean(name='test_loss')

# %%
learning_rate = 0.0001

optimizer = Adam(learning_rate=learning_rate)

# %%
EPOCHS = 30
ROUNDS = 3
BUFFER_SIZE = 1000
BATCH_SIZE = 128

# %% [markdown]
# # Checkpoint

# %%
checkpoint_path = "./checkpoints/restaurant/"
ckpt = Checkpoint(cnn_model, optimizer=optimizer)
ckpt_manager = CheckpointManager(ckpt, checkpoint_path, max_to_keep=50)

# %%
@tf.function
def train_step(inp, out):
    with tf.GradientTape() as tape:
        pred = cnn_model(inp, True)

        loss = loss_function(out, pred)
    
    gradients = tape.gradient(loss, cnn_model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, cnn_model.trainable_variables))

    train_loss(loss)

# %% [markdown]
# # Training

# %%
def teacher(round, train_inp, dev_inp, dev_out, seed_set):
    print('TEACHER:')
    
    weight_seed = {}

    if round == 0:
        weight_seed = default_weight_seed
    else:
        student_train_pred = cnn_model(train_inp, True)
        student_train_pred = tf.argmax(student_train_pred, axis=1)
        weight_seed = get_weight_seed(train_inp, student_train_pred, seed_set)
    
    dev_pred = get_train_weak_out(dev_inp, seed_set, weight_seed)
    
    dev_acc = accuracy_score(tf.argmax(dev_out, axis=1), tf.argmax(dev_pred, axis=1))

    print(f'Dev Accuracy: {dev_acc:.4f}')
    print()

    return weight_seed

# %%
def student(num_epochs, train_inp, dev_inp, dev_out, seed_set, weight_seed):
    print('STUDENT:')
    
    train_out = get_train_weak_out(train_inp, seed_set, weight_seed)

    train_examples = Dataset.from_tensor_slices((train_inp, train_out))

    train_batches = train_examples.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

    best_epoch = 0
    best_dev_acc = 0

    for epoch in range(num_epochs):
        start = time.time()

        train_loss.reset_states()

        for (batch, (inp, out)) in enumerate(train_batches):
            train_step(inp, out)
            if batch % 200 == 0:
                print(f'Epoch {epoch + 1} Batch {batch} Loss {train_loss.result():.4f}')

        dev_loss.reset_states()

        dev_inp_tensor = tf.constant(dev_inp)
        dev_out_tensor = tf.constant(dev_out)

        dev_pred = cnn_model(dev_inp_tensor, True)
        loss = loss_function(dev_out_tensor, dev_pred)
        dev_acc = accuracy_score(tf.argmax(dev_out_tensor, axis=1), tf.argmax(dev_pred, axis=1))

        if dev_acc > best_dev_acc:
            best_dev_acc = dev_acc
            best_epoch = epoch
        
        dev_loss(loss)

        if (epoch + 1) % 1 == 0:
            ckpt_save_path = ckpt_manager.save()
            print(f'Saving checkpoint for epoch {epoch+1} at {ckpt_save_path}')
        
        print(f'Epoch {epoch + 1}: Loss {train_loss.result():.4f}')
    
        print(f'Dev loss: {dev_loss.result():.4f} Dev Accuracy: {dev_acc:.4f}')
    
        print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')

    return best_epoch

# %%
epoch = 0

# %%
for round in range(ROUNDS):

    print(f'ROUND {round + 1}:')
    
    # TEACHER
    weight_seed = teacher(round, train_inp, dev_inp, dev_out, seed_set)
        
    # STUDENT
    best_epoch = student(EPOCHS, train_inp, dev_inp, dev_out, seed_set, weight_seed) + 1
    epoch = epoch + best_epoch

    # Restore best epoch
    ckpt.restore(checkpoint_path + 'ckpt-' + str(epoch))
    print(f'Restore best epoch\n')

    # Teacher's result
    teacher_test_pred = get_train_weak_out(test_inp, seed_set, weight_seed)
    teacher_f1 = f1_score(tf.argmax(test_out, axis=1), tf.argmax(teacher_test_pred, axis=1), average='macro')
    tch_clfrpt = classification_report(tf.argmax(test_out, axis=1), tf.argmax(teacher_test_pred, axis=1))

    print('TEACHER:')
    print(f'Test F1 Score: {teacher_f1:.4f}\n')
    print(tch_clfrpt)

    # Student's result
    test_inp_tensor = tf.constant(test_inp)
    test_out_tensor = tf.constant(test_out)
    
    student_test_pred = cnn_model(test_inp_tensor, True)
    student_f1 = f1_score(tf.argmax(test_out_tensor, axis=1), tf.argmax(student_test_pred, axis=1), average='macro')
    std_clfrpt = classification_report(tf.argmax(test_out_tensor, axis=1), tf.argmax(student_test_pred, axis=1))

    print('STUDENT:')
    print(f'Test F1 Score: {student_f1:.4f}\n')
    print(std_clfrpt)
# Out:
# ROUND 1:
# TEACHER:
# Dev Accuracy: 0.7727
#
# STUDENT:
# Epoch 1 Batch 0 Loss 1.7912
# Epoch 1 Batch 200 Loss 1.6748
# Saving checkpoint for epoch 1 at ./checkpoints/restaurant/ckpt-1
# Epoch 1: Loss 1.6657
# Dev loss: 1.3764 Dev Accuracy: 0.5000
# Time taken for 1 epoch: 10.71 secs
#
# Epoch 2 Batch 0 Loss 1.4194
# Epoch 2 Batch 200 Loss 1.5008
# Saving checkpoint for epoch 2 at ./checkpoints/restaurant/ckpt-2
# Epoch 2: Loss 1.4990
# Dev loss: 1.1973 Dev Accuracy: 0.6420
# Time taken for 1 epoch: 10.40 secs
#
# Epoch 3 Batch 0 Loss 1.3075
# Epoch 3 Batch 200 Loss 1.3860
# Saving checkpoint for epoch 3 at ./checkpoints/restaurant/ckpt-3
# Epoch 3: Loss 1.3863
# Dev loss: 1.0659 Dev Accuracy: 0.7045
# Time taken for 1 epoch: 9.29 secs
#
# Epoch 4 Batch 0 Loss 1.1558
# Epoch 4 Batch 200 Loss 1.3301
# Saving checkpoint for epoch 4 at ./checkpoints/restaurant/ckpt-4
# Epoch 4: Loss 1.3326
# Dev loss: 1.0354 Dev Accuracy: 0.7244
# Time taken for 1 epoch: 10.64 secs
#
# Epoch 5 Batch 0 Loss 1.3015
# Epoch 5 Batch 200 Loss 1.2995
# Saving checkpoint for epoch 5 at ./checkpoints/restaurant/ckpt-5
# Epoch 5: Loss 1.3022
# Dev loss: 1.0573 Dev Accuracy: 0.7102
# Time taken for 1 epoch: 10.74 secs
#
# Epoch 6 Batch 0 Loss 1.1639
# Epoch 6 Batch 200 Loss 1.2757
# Saving checkpoint for epoch 6 at ./checkpoints/restaurant/ckpt-6
# Epoch 6: Loss 1.2787
# Dev loss: 1.0501 Dev Accuracy: 0.7386
# Time taken for 1 epoch: 10.43 secs
#
# Epoch 7 Batch 0 Loss 1.2329
# Epoch 7 Batch 200 Loss 1.2565
# Saving checkpoint for epoch 7 at ./checkpoints/restaurant/ckpt-7
# Epoch 7: Loss 1.2596
# Dev loss: 1.0693 Dev Accuracy: 0.7415
# Time taken for 1 epoch: 10.39 secs
#
# Epoch 8 Batch 0 Loss 1.1619
# Epoch 8 Batch 200 Loss 1.2416
# Saving checkpoint for epoch 8 at ./checkpoints/restaurant/ckpt-8
# Epoch 8: Loss 1.2445
# Dev loss: 1.1649 Dev Accuracy: 0.7216
# Time taken for 1 epoch: 10.63 secs
#
# Epoch 9 Batch 0 Loss 1.1587
# Epoch 9 Batch 200 Loss 1.2321
# Saving checkpoint for epoch 9 at ./checkpoints/restaurant/ckpt-9
# Epoch 9: Loss 1.2346
# Dev loss: 1.1491 Dev Accuracy: 0.7500
# Time taken for 1 epoch: 9.79 secs
#
# Epoch 10 Batch 0 Loss 1.2689
# Epoch 10 Batch 200 Loss 1.2244
# Saving checkpoint for epoch 10 at ./checkpoints/restaurant/ckpt-10
# Epoch 10: Loss 1.2276
# Dev loss: 1.1839 Dev Accuracy: 0.7415
# Time taken for 1 epoch: 10.18 secs
#
# Epoch 11 Batch 0 Loss 1.0956
# Epoch 11 Batch 200 Loss 1.2200
# Saving checkpoint for epoch 11 at ./checkpoints/restaurant/ckpt-11
# Epoch 11: Loss 1.2220
# Dev loss: 1.2097 Dev Accuracy: 0.7528
# Time taken for 1 epoch: 9.98 secs
#
# Epoch 12 Batch 0 Loss 1.1254
# Epoch 12 Batch 200 Loss 1.2160
# Saving checkpoint for epoch 12 at ./checkpoints/restaurant/ckpt-12
# Epoch 12: Loss 1.2183
# Dev loss: 1.2472 Dev Accuracy: 0.7614
# Time taken for 1 epoch: 10.53 secs
#
# Epoch 13 Batch 0 Loss 1.1214
# Epoch 13 Batch 200 Loss 1.2117
# Saving checkpoint for epoch 13 at ./checkpoints/restaurant/ckpt-13
# Epoch 13: Loss 1.2150
# Dev loss: 1.2705 Dev Accuracy: 0.7386
# Time taken for 1 epoch: 10.69 secs
#
# Epoch 14 Batch 0 Loss 1.0988
# Epoch 14 Batch 200 Loss 1.2100
# Saving checkpoint for epoch 14 at ./checkpoints/restaurant/ckpt-14
# Epoch 14: Loss 1.2128
# Dev loss: 1.2868 Dev Accuracy: 0.7443
# Time taken for 1 epoch: 10.72 secs
#
# Epoch 15 Batch 0 Loss 1.1036
# Epoch 15 Batch 200 Loss 1.2082
# Saving checkpoint for epoch 15 at ./checkpoints/restaurant/ckpt-15
# Epoch 15: Loss 1.2113
# Dev loss: 1.2838 Dev Accuracy: 0.7443
# Time taken for 1 epoch: 10.48 secs
#
# Epoch 16 Batch 0 Loss 1.1223
# Epoch 16 Batch 200 Loss 1.2070
# Saving checkpoint for epoch 16 at ./checkpoints/restaurant/ckpt-16
# Epoch 16: Loss 1.2102
# Dev loss: 1.3166 Dev Accuracy: 0.7358
# Time taken for 1 epoch: 10.43 secs
#
# Epoch 17 Batch 0 Loss 1.1752
# Epoch 17 Batch 200 Loss 1.2066
# Saving checkpoint for epoch 17 at ./checkpoints/restaurant/ckpt-17
# Epoch 17: Loss 1.2090
# Dev loss: 1.3191 Dev Accuracy: 0.7528
# Time taken for 1 epoch: 10.58 secs
#
# Epoch 18 Batch 0 Loss 1.0948
# Epoch 18 Batch 200 Loss 1.2049
# Saving checkpoint for epoch 18 at ./checkpoints/restaurant/ckpt-18
# Epoch 18: Loss 1.2082
# Dev loss: 1.3235 Dev Accuracy: 0.7585
# Time taken for 1 epoch: 11.61 secs
#
# Epoch 19 Batch 0 Loss 1.2129
# Epoch 19 Batch 200 Loss 1.2054
# Saving checkpoint for epoch 19 at ./checkpoints/restaurant/ckpt-19
# Epoch 19: Loss 1.2074
# Dev loss: 1.3468 Dev Accuracy: 0.7301
# Time taken for 1 epoch: 11.05 secs
#
# Epoch 20 Batch 0 Loss 1.1015
# Epoch 20 Batch 200 Loss 1.2038
# Saving checkpoint for epoch 20 at ./checkpoints/restaurant/ckpt-20
# Epoch 20: Loss 1.2066
# Dev loss: 1.3865 Dev Accuracy: 0.7585
# Time taken for 1 epoch: 11.84 secs
#
# Epoch 21 Batch 0 Loss 1.0212
# Epoch 21 Batch 200 Loss 1.2035
# Saving checkpoint for epoch 21 at ./checkpoints/restaurant/ckpt-21
# Epoch 21: Loss 1.2061
# Dev loss: 1.3722 Dev Accuracy: 0.7614
# Time taken for 1 epoch: 11.86 secs
#
# Epoch 22 Batch 0 Loss 1.1075
# Epoch 22 Batch 200 Loss 1.2032
# Saving checkpoint for epoch 22 at ./checkpoints/restaurant/ckpt-22
# Epoch 22: Loss 1.2059
# Dev loss: 1.3968 Dev Accuracy: 0.7472
# Time taken for 1 epoch: 12.19 secs
#
# Epoch 23 Batch 0 Loss 1.0195
# Epoch 23 Batch 200 Loss 1.2034
# Saving checkpoint for epoch 23 at ./checkpoints/restaurant/ckpt-23
# Epoch 23: Loss 1.2053
# Dev loss: 1.3937 Dev Accuracy: 0.7557
# Time taken for 1 epoch: 11.88 secs
#
# Epoch 24 Batch 0 Loss 1.1067
# Epoch 24 Batch 200 Loss 1.2018
# Saving checkpoint for epoch 24 at ./checkpoints/restaurant/ckpt-24
# Epoch 24: Loss 1.2048
# Dev loss: 1.3875 Dev Accuracy: 0.7528
# Time taken for 1 epoch: 12.50 secs
#
# Epoch 25 Batch 0 Loss 1.1045
# Epoch 25 Batch 200 Loss 1.2017
# Saving checkpoint for epoch 25 at ./checkpoints/restaurant/ckpt-25
# Epoch 25: Loss 1.2042
# Dev loss: 1.3926 Dev Accuracy: 0.7528
# Time taken for 1 epoch: 11.53 secs
#
# Epoch 26 Batch 0 Loss 1.1857
# Epoch 26 Batch 200 Loss 1.2014
# Saving checkpoint for epoch 26 at ./checkpoints/restaurant/ckpt-26
# Epoch 26: Loss 1.2039
# Dev loss: 1.4356 Dev Accuracy: 0.7557
# Time taken for 1 epoch: 11.85 secs
#
# Epoch 27 Batch 0 Loss 1.1668
# Epoch 27 Batch 200 Loss 1.2011
# Saving checkpoint for epoch 27 at ./checkpoints/restaurant/ckpt-27
# Epoch 27: Loss 1.2036
# Dev loss: 1.4554 Dev Accuracy: 0.7528
# Time taken for 1 epoch: 10.84 secs
#
# Epoch 28 Batch 0 Loss 1.1088
# Epoch 28 Batch 200 Loss 1.2005
# Saving checkpoint for epoch 28 at ./checkpoints/restaurant/ckpt-28
# Epoch 28: Loss 1.2038
# Dev loss: 1.4707 Dev Accuracy: 0.7528
# Time taken for 1 epoch: 10.86 secs
#
# Epoch 29 Batch 0 Loss 1.1405
# Epoch 29 Batch 200 Loss 1.2005
# Saving checkpoint for epoch 29 at ./checkpoints/restaurant/ckpt-29
# Epoch 29: Loss 1.2030
# Dev loss: 1.4572 Dev Accuracy: 0.7614
# Time taken for 1 epoch: 10.51 secs
#
# Epoch 30 Batch 0 Loss 1.1225
# Epoch 30 Batch 200 Loss 1.1998
# Saving checkpoint for epoch 30 at ./checkpoints/restaurant/ckpt-30
# Epoch 30: Loss 1.2028
# Dev loss: 1.4326 Dev Accuracy: 0.7557
# Time taken for 1 epoch: 11.09 secs
#
# Restore best epoch
#
# TEACHER:
# Test F1 Score: 0.5334
#
#               precision    recall  f1-score   support
#
#            0       0.26      0.67      0.37        57
#            1       0.90      0.71      0.80       355
#            2       0.66      0.64      0.65        36
#            3       0.48      0.55      0.51        22
#            4       0.52      0.48      0.50        31
#            5       0.57      0.28      0.37        29
#
#     accuracy                           0.66       530
#    macro avg       0.56      0.55      0.53       530
# weighted avg       0.76      0.66      0.69       530
#
# STUDENT:
# Test F1 Score: 0.5426
#
#               precision    recall  f1-score   support
#
#            0       0.24      0.51      0.33        57
#            1       0.91      0.72      0.80       355
#            2       0.64      0.64      0.64        36
#            3       0.41      0.59      0.48        22
#            4       0.46      0.61      0.53        31
#            5       0.57      0.41      0.48        29
#
#     accuracy                           0.66       530
#    macro avg       0.54      0.58      0.54       530
# weighted avg       0.75      0.66      0.69       530
#
# ROUND 2:
# TEACHER:
# Dev Accuracy: 0.7955
#
# STUDENT:
# Epoch 1 Batch 0 Loss 1.1202
# Epoch 1 Batch 200 Loss 1.3379
# Saving checkpoint for epoch 1 at ./checkpoints/restaurant/ckpt-13
# Epoch 1: Loss 1.3401
# Dev loss: 1.3626 Dev Accuracy: 0.7727
# Time taken for 1 epoch: 9.41 secs
#
# Epoch 2 Batch 0 Loss 1.0926
# Epoch 2 Batch 200 Loss 1.3298
# Saving checkpoint for epoch 2 at ./checkpoints/restaurant/ckpt-14
# Epoch 2: Loss 1.3335
# Dev loss: 1.4158 Dev Accuracy: 0.7670
# Time taken for 1 epoch: 9.43 secs
#
# Epoch 3 Batch 0 Loss 1.2098
# Epoch 3 Batch 200 Loss 1.3280
# Saving checkpoint for epoch 3 at ./checkpoints/restaurant/ckpt-15
# Epoch 3: Loss 1.3317
# Dev loss: 1.4610 Dev Accuracy: 0.7784
# Time taken for 1 epoch: 9.51 secs
#
# Epoch 4 Batch 0 Loss 1.2752
# Epoch 4 Batch 200 Loss 1.3283
# Saving checkpoint for epoch 4 at ./checkpoints/restaurant/ckpt-16
# Epoch 4: Loss 1.3306
# Dev loss: 1.4396 Dev Accuracy: 0.7756
# Time taken for 1 epoch: 10.38 secs
#
# Epoch 5 Batch 0 Loss 1.2610
# Epoch 5 Batch 200 Loss 1.3276
# Saving checkpoint for epoch 5 at ./checkpoints/restaurant/ckpt-17
# Epoch 5: Loss 1.3299
# Dev loss: 1.4241 Dev Accuracy: 0.7812
# Time taken for 1 epoch: 10.31 secs
#
# Epoch 6 Batch 0 Loss 1.1128
# Epoch 6 Batch 200 Loss 1.3258
# Saving checkpoint for epoch 6 at ./checkpoints/restaurant/ckpt-18
# Epoch 6: Loss 1.3292
# Dev loss: 1.4489 Dev Accuracy: 0.7812
# Time taken for 1 epoch: 10.69 secs
#
# Epoch 7 Batch 0 Loss 1.1954
# Epoch 7 Batch 200 Loss 1.3256
# Saving checkpoint for epoch 7 at ./checkpoints/restaurant/ckpt-19
# Epoch 7: Loss 1.3288
# Dev loss: 1.5110 Dev Accuracy: 0.7756
# Time taken for 1 epoch: 10.30 secs
#
# Epoch 8 Batch 0 Loss 1.2754
# Epoch 8 Batch 200 Loss 1.3252
# Saving checkpoint for epoch 8 at ./checkpoints/restaurant/ckpt-20
# Epoch 8: Loss 1.3284
# Dev loss: 1.4788 Dev Accuracy: 0.7869
# Time taken for 1 epoch: 9.95 secs
#
# Epoch 9 Batch 0 Loss 1.1970
# Epoch 9 Batch 200 Loss 1.3239
# Saving checkpoint for epoch 9 at ./checkpoints/restaurant/ckpt-21
# Epoch 9: Loss 1.3279
# Dev loss: 1.5260 Dev Accuracy: 0.7812
# Time taken for 1 epoch: 10.20 secs
#
# Epoch 10 Batch 0 Loss 1.2364
# Epoch 10 Batch 200 Loss 1.3243
# Saving checkpoint for epoch 10 at ./checkpoints/restaurant/ckpt-22
# Epoch 10: Loss 1.3276
# Dev loss: 1.4926 Dev Accuracy: 0.7869
# Time taken for 1 epoch: 10.24 secs
#
# Epoch 11 Batch 0 Loss 1.1546
# Epoch 11 Batch 200 Loss 1.3248
# Saving checkpoint for epoch 11 at ./checkpoints/restaurant/ckpt-23
# Epoch 11: Loss 1.3275
# Dev loss: 1.6219 Dev Accuracy: 0.7756
# Time taken for 1 epoch: 10.16 secs
#
# Epoch 12 Batch 0 Loss 1.3586
# Epoch 12 Batch 200 Loss 1.3237
# Saving checkpoint for epoch 12 at ./checkpoints/restaurant/ckpt-24
# Epoch 12: Loss 1.3272
# Dev loss: 1.6192 Dev Accuracy: 0.7841
# Time taken for 1 epoch: 10.18 secs
#
# Epoch 13 Batch 0 Loss 1.1339
# Epoch 13 Batch 200 Loss 1.3228
# Saving checkpoint for epoch 13 at ./checkpoints/restaurant/ckpt-25
# Epoch 13: Loss 1.3270
# Dev loss: 1.5639 Dev Accuracy: 0.7784
# Time taken for 1 epoch: 10.14 secs
#
# Epoch 14 Batch 0 Loss 1.1999
# Epoch 14 Batch 200 Loss 1.3247
# Saving checkpoint for epoch 14 at ./checkpoints/restaurant/ckpt-26
# Epoch 14: Loss 1.3269
# Dev loss: 1.5940 Dev Accuracy: 0.7898
# Time taken for 1 epoch: 10.80 secs
#
# Epoch 15 Batch 0 Loss 1.2077
# Epoch 15 Batch 200 Loss 1.3243
# Saving checkpoint for epoch 15 at ./checkpoints/restaurant/ckpt-27
# Epoch 15: Loss 1.3265
# Dev loss: 1.6270 Dev Accuracy: 0.7727
# Time taken for 1 epoch: 10.94 secs
#
# Epoch 16 Batch 0 Loss 1.1808
# Epoch 16 Batch 200 Loss 1.3223
# Saving checkpoint for epoch 16 at ./checkpoints/restaurant/ckpt-28
# Epoch 16: Loss 1.3264
# Dev loss: 1.6204 Dev Accuracy: 0.7898
# Time taken for 1 epoch: 9.99 secs
#
# Epoch 17 Batch 0 Loss 1.1987
# Epoch 17 Batch 200 Loss 1.3226
# Saving checkpoint for epoch 17 at ./checkpoints/restaurant/ckpt-29
# Epoch 17: Loss 1.3262
# Dev loss: 1.6450 Dev Accuracy: 0.7983
# Time taken for 1 epoch: 9.63 secs
#
# Epoch 18 Batch 0 Loss 1.2813
# Epoch 18 Batch 200 Loss 1.3234
# Saving checkpoint for epoch 18 at ./checkpoints/restaurant/ckpt-30
# Epoch 18: Loss 1.3261
# Dev loss: 1.5786 Dev Accuracy: 0.7812
# Time taken for 1 epoch: 10.05 secs
#
# Epoch 19 Batch 0 Loss 1.2614
# Epoch 19 Batch 200 Loss 1.3220
# Saving checkpoint for epoch 19 at ./checkpoints/restaurant/ckpt-31
# Epoch 19: Loss 1.3260
# Dev loss: 1.7141 Dev Accuracy: 0.7784
# Time taken for 1 epoch: 10.59 secs
#
# Epoch 20 Batch 0 Loss 1.2263
# Epoch 20 Batch 200 Loss 1.3229
# Saving checkpoint for epoch 20 at ./checkpoints/restaurant/ckpt-32
# Epoch 20: Loss 1.3258
# Dev loss: 1.6037 Dev Accuracy: 0.7784
# Time taken for 1 epoch: 10.65 secs
#
# Epoch 21 Batch 0 Loss 1.2046
# Epoch 21 Batch 200 Loss 1.3228
# Saving checkpoint for epoch 21 at ./checkpoints/restaurant/ckpt-33
# Epoch 21: Loss 1.3257
# Dev loss: 1.6938 Dev Accuracy: 0.7955
# Time taken for 1 epoch: 10.19 secs
#
# Epoch 22 Batch 0 Loss 1.2095
# Epoch 22 Batch 200 Loss 1.3219
# Saving checkpoint for epoch 22 at ./checkpoints/restaurant/ckpt-34
# Epoch 22: Loss 1.3256
# Dev loss: 1.6186 Dev Accuracy: 0.7812
# Time taken for 1 epoch: 10.49 secs
#
# Epoch 23 Batch 0 Loss 1.2005
# Epoch 23 Batch 200 Loss 1.3221
# Saving checkpoint for epoch 23 at ./checkpoints/restaurant/ckpt-35
# Epoch 23: Loss 1.3256
# Dev loss: 1.6155 Dev Accuracy: 0.7756
# Time taken for 1 epoch: 9.90 secs
#
# Epoch 24 Batch 0 Loss 1.1981
# Epoch 24 Batch 200 Loss 1.3222
# Saving checkpoint for epoch 24 at ./checkpoints/restaurant/ckpt-36
# Epoch 24: Loss 1.3254
# Dev loss: 1.7028 Dev Accuracy: 0.7812
# Time taken for 1 epoch: 12.99 secs
#
# Epoch 25 Batch 0 Loss 1.2791
# Epoch 25 Batch 200 Loss 1.3217
# Saving checkpoint for epoch 25 at ./checkpoints/restaurant/ckpt-37
# Epoch 25: Loss 1.3253
# Dev loss: 1.7058 Dev Accuracy: 0.7841
# Time taken for 1 epoch: 12.02 secs
#
# Epoch 26 Batch 0 Loss 1.1471
# Epoch 26 Batch 200 Loss 1.3217
# Saving checkpoint for epoch 26 at ./checkpoints/restaurant/ckpt-38
# Epoch 26: Loss 1.3252
# Dev loss: 1.5764 Dev Accuracy: 0.7812
# Time taken for 1 epoch: 11.01 secs
#
# Epoch 27 Batch 0 Loss 1.2488
# Epoch 27 Batch 200 Loss 1.3226
# Saving checkpoint for epoch 27 at ./checkpoints/restaurant/ckpt-39
# Epoch 27: Loss 1.3251
# Dev loss: 1.6838 Dev Accuracy: 0.7926
# Time taken for 1 epoch: 10.51 secs
#
# Epoch 28 Batch 0 Loss 1.2391
# Epoch 28 Batch 200 Loss 1.3221
# Saving checkpoint for epoch 28 at ./checkpoints/restaurant/ckpt-40
# Epoch 28: Loss 1.3251
# Dev loss: 1.6735 Dev Accuracy: 0.7955
# Time taken for 1 epoch: 11.19 secs
#
# Epoch 29 Batch 0 Loss 1.2384
# Epoch 29 Batch 200 Loss 1.3213
# Saving checkpoint for epoch 29 at ./checkpoints/restaurant/ckpt-41
# Epoch 29: Loss 1.3251
# Dev loss: 1.5895 Dev Accuracy: 0.7898
# Time taken for 1 epoch: 11.10 secs
#
# Epoch 30 Batch 0 Loss 1.2559
# Epoch 30 Batch 200 Loss 1.3227
# Saving checkpoint for epoch 30 at ./checkpoints/restaurant/ckpt-42
# Epoch 30: Loss 1.3248
# Dev loss: 1.7197 Dev Accuracy: 0.7926
# Time taken for 1 epoch: 10.37 secs
#
# Restore best epoch
#
# TEACHER:
# Test F1 Score: 0.5791
#
#               precision    recall  f1-score   support
#
#            0       0.30      0.60      0.40        57
#            1       0.88      0.77      0.82       355
#            2       0.66      0.58      0.62        36
#            3       0.61      0.64      0.62        22
#            4       0.50      0.58      0.54        31
#            5       0.65      0.38      0.48        29
#
#     accuracy                           0.70       530
#    macro avg       0.60      0.59      0.58       530
# weighted avg       0.76      0.70      0.72       530
#
# STUDENT:
# Test F1 Score: 0.5515
#
#               precision    recall  f1-score   support
#
#            0       0.29      0.58      0.39        57
#            1       0.88      0.77      0.82       355
#            2       0.65      0.56      0.60        36
#            3       0.58      0.50      0.54        22
#            4       0.47      0.55      0.51        31
#            5       0.58      0.38      0.46        29
#
#     accuracy                           0.69       530
#    macro avg       0.57      0.56      0.55       530
# weighted avg       0.75      0.69      0.71       530
#
# ROUND 3:
# TEACHER:
# Dev Accuracy: 0.7898
#
# STUDENT:
# Epoch 1 Batch 0 Loss 1.1460
# Epoch 1 Batch 200 Loss 1.2943
# Saving checkpoint for epoch 1 at ./checkpoints/restaurant/ckpt-30
# Epoch 1: Loss 1.2986
# Dev loss: 1.4360 Dev Accuracy: 0.7812
# Time taken for 1 epoch: 9.48 secs
#
# Epoch 2 Batch 0 Loss 1.2167
# Epoch 2 Batch 200 Loss 1.2941
# Saving checkpoint for epoch 2 at ./checkpoints/restaurant/ckpt-31
# Epoch 2: Loss 1.2979
# Dev loss: 1.5733 Dev Accuracy: 0.7898
# Time taken for 1 epoch: 8.01 secs
#
# Epoch 3 Batch 0 Loss 1.2336
# Epoch 3 Batch 200 Loss 1.2942
# Saving checkpoint for epoch 3 at ./checkpoints/restaurant/ckpt-32
# Epoch 3: Loss 1.2977
# Dev loss: 1.5457 Dev Accuracy: 0.7812
# Time taken for 1 epoch: 9.66 secs
#
# Epoch 4 Batch 0 Loss 1.2077
# Epoch 4 Batch 200 Loss 1.2929
# Saving checkpoint for epoch 4 at ./checkpoints/restaurant/ckpt-33
# Epoch 4: Loss 1.2977
# Dev loss: 1.6018 Dev Accuracy: 0.7869
# Time taken for 1 epoch: 8.86 secs
#
# Epoch 5 Batch 0 Loss 1.0511
# Epoch 5 Batch 200 Loss 1.2936
# Saving checkpoint for epoch 5 at ./checkpoints/restaurant/ckpt-34
# Epoch 5: Loss 1.2976
# Dev loss: 1.5962 Dev Accuracy: 0.7898
# Time taken for 1 epoch: 9.56 secs
#
# Epoch 6 Batch 0 Loss 1.3062
# Epoch 6 Batch 200 Loss 1.2923
# Saving checkpoint for epoch 6 at ./checkpoints/restaurant/ckpt-35
# Epoch 6: Loss 1.2974
# Dev loss: 1.5948 Dev Accuracy: 0.7898
# Time taken for 1 epoch: 9.76 secs
#
# Epoch 7 Batch 0 Loss 1.2202
# Epoch 7 Batch 200 Loss 1.2937
# Saving checkpoint for epoch 7 at ./checkpoints/restaurant/ckpt-36
# Epoch 7: Loss 1.2973
# Dev loss: 1.6156 Dev Accuracy: 0.7983
# Time taken for 1 epoch: 9.73 secs
#
# Epoch 8 Batch 0 Loss 1.1404
# Epoch 8 Batch 200 Loss 1.2918
# Saving checkpoint for epoch 8 at ./checkpoints/restaurant/ckpt-37
# Epoch 8: Loss 1.2971
# Dev loss: 1.6830 Dev Accuracy: 0.7898
# Time taken for 1 epoch: 9.34 secs
#
# Epoch 9 Batch 0 Loss 1.2611
# Epoch 9 Batch 200 Loss 1.2930
# Saving checkpoint for epoch 9 at ./checkpoints/restaurant/ckpt-38
# Epoch 9: Loss 1.2970
# Dev loss: 1.5881 Dev Accuracy: 0.7898
# Time taken for 1 epoch: 10.53 secs
#
# Epoch 10 Batch 0 Loss 1.2299
# Epoch 10 Batch 200 Loss 1.2924
# Saving checkpoint for epoch 10 at ./checkpoints/restaurant/ckpt-39
# Epoch 10: Loss 1.2969
# Dev loss: 1.6948 Dev Accuracy: 0.7784
# Time taken for 1 epoch: 10.27 secs
#
# Epoch 11 Batch 0 Loss 1.2178
# Epoch 11 Batch 200 Loss 1.2930
# Saving checkpoint for epoch 11 at ./checkpoints/restaurant/ckpt-40
# Epoch 11: Loss 1.2968
# Dev loss: 1.6770 Dev Accuracy: 0.7898
# Time taken for 1 epoch: 10.28 secs
#
# Epoch 12 Batch 0 Loss 1.1093
# Epoch 12 Batch 200 Loss 1.2923
# Saving checkpoint for epoch 12 at ./checkpoints/restaurant/ckpt-41
# Epoch 12: Loss 1.2969
# Dev loss: 1.5845 Dev Accuracy: 0.7784
# Time taken for 1 epoch: 10.31 secs
#
# Epoch 13 Batch 0 Loss 1.1597
# Epoch 13 Batch 200 Loss 1.2920
# Saving checkpoint for epoch 13 at ./checkpoints/restaurant/ckpt-42
# Epoch 13: Loss 1.2967
# Dev loss: 1.7408 Dev Accuracy: 0.7756
# Time taken for 1 epoch: 10.59 secs
#
# Epoch 14 Batch 0 Loss 1.2867
# Epoch 14 Batch 200 Loss 1.2920
# Saving checkpoint for epoch 14 at ./checkpoints/restaurant/ckpt-43
# Epoch 14: Loss 1.2967
# Dev loss: 1.5860 Dev Accuracy: 0.7841
# Time taken for 1 epoch: 9.55 secs
#
# Epoch 15 Batch 0 Loss 1.2143
# Epoch 15 Batch 200 Loss 1.2920
# Saving checkpoint for epoch 15 at ./checkpoints/restaurant/ckpt-44
# Epoch 15: Loss 1.2966
# Dev loss: 1.7100 Dev Accuracy: 0.7812
# Time taken for 1 epoch: 10.11 secs
#
# Epoch 16 Batch 0 Loss 1.1256
# Epoch 16 Batch 200 Loss 1.2928
# Saving checkpoint for epoch 16 at ./checkpoints/restaurant/ckpt-45
# Epoch 16: Loss 1.2965
# Dev loss: 1.6874 Dev Accuracy: 0.7869
# Time taken for 1 epoch: 10.39 secs
#
# Epoch 17 Batch 0 Loss 1.2416
# Epoch 17 Batch 200 Loss 1.2909
# Saving checkpoint for epoch 17 at ./checkpoints/restaurant/ckpt-46
# Epoch 17: Loss 1.2964
# Dev loss: 1.7234 Dev Accuracy: 0.7898
# Time taken for 1 epoch: 10.30 secs
#
# Epoch 18 Batch 0 Loss 1.2056
# Epoch 18 Batch 200 Loss 1.2917
# Saving checkpoint for epoch 18 at ./checkpoints/restaurant/ckpt-47
# Epoch 18: Loss 1.2963
# Dev loss: 1.7703 Dev Accuracy: 0.7727
# Time taken for 1 epoch: 10.65 secs
#
# Epoch 19 Batch 0 Loss 1.1345
# Epoch 19 Batch 200 Loss 1.2922
# Saving checkpoint for epoch 19 at ./checkpoints/restaurant/ckpt-48
# Epoch 19: Loss 1.2962
# Dev loss: 1.7149 Dev Accuracy: 0.7869
# Time taken for 1 epoch: 11.27 secs
#
# Epoch 20 Batch 0 Loss 1.1852
# Epoch 20 Batch 200 Loss 1.2922
# Saving checkpoint for epoch 20 at ./checkpoints/restaurant/ckpt-49
# Epoch 20: Loss 1.2963
# Dev loss: 1.7073 Dev Accuracy: 0.7869
# Time taken for 1 epoch: 10.44 secs
#
# Epoch 21 Batch 0 Loss 1.1513
# Epoch 21 Batch 200 Loss 1.2915
# Saving checkpoint for epoch 21 at ./checkpoints/restaurant/ckpt-50
# Epoch 21: Loss 1.2963
# Dev loss: 1.6757 Dev Accuracy: 0.7841
# Time taken for 1 epoch: 11.19 secs
#
# Epoch 22 Batch 0 Loss 1.1586
# Epoch 22 Batch 200 Loss 1.2919
# Saving checkpoint for epoch 22 at ./checkpoints/restaurant/ckpt-51
# Epoch 22: Loss 1.2961
# Dev loss: 1.7696 Dev Accuracy: 0.7898
# Time taken for 1 epoch: 10.44 secs
#
# Epoch 23 Batch 0 Loss 1.2684
# Epoch 23 Batch 200 Loss 1.2915
# Saving checkpoint for epoch 23 at ./checkpoints/restaurant/ckpt-52
# Epoch 23: Loss 1.2961
# Dev loss: 1.5358 Dev Accuracy: 0.7812
# Time taken for 1 epoch: 9.81 secs
#
# Epoch 24 Batch 0 Loss 1.1259
# Epoch 24 Batch 200 Loss 1.2909
# Saving checkpoint for epoch 24 at ./checkpoints/restaurant/ckpt-53
# Epoch 24: Loss 1.2960
# Dev loss: 1.7211 Dev Accuracy: 0.7756
# Time taken for 1 epoch: 9.59 secs
#
# Epoch 25 Batch 0 Loss 1.1948
# Epoch 25 Batch 200 Loss 1.2917
# Saving checkpoint for epoch 25 at ./checkpoints/restaurant/ckpt-54
# Epoch 25: Loss 1.2960
# Dev loss: 1.7152 Dev Accuracy: 0.7812
# Time taken for 1 epoch: 10.18 secs
#
# Epoch 26 Batch 0 Loss 1.2297
# Epoch 26 Batch 200 Loss 1.2915
# Saving checkpoint for epoch 26 at ./checkpoints/restaurant/ckpt-55
# Epoch 26: Loss 1.2959
# Dev loss: 1.6697 Dev Accuracy: 0.7869
# Time taken for 1 epoch: 9.98 secs
#
# Epoch 27 Batch 0 Loss 1.1891
# Epoch 27 Batch 200 Loss 1.2909
# Saving checkpoint for epoch 27 at ./checkpoints/restaurant/ckpt-56
# Epoch 27: Loss 1.2959
# Dev loss: 1.5385 Dev Accuracy: 0.7812
# Time taken for 1 epoch: 9.55 secs
#
# Epoch 28 Batch 0 Loss 1.1475
# Epoch 28 Batch 200 Loss 1.2911
# Saving checkpoint for epoch 28 at ./checkpoints/restaurant/ckpt-57
# Epoch 28: Loss 1.2958
# Dev loss: 1.7081 Dev Accuracy: 0.7869
# Time taken for 1 epoch: 9.64 secs
#
# Epoch 29 Batch 0 Loss 1.0639
# Epoch 29 Batch 200 Loss 1.2904
# Saving checkpoint for epoch 29 at ./checkpoints/restaurant/ckpt-58
# Epoch 29: Loss 1.2958
# Dev loss: 1.7742 Dev Accuracy: 0.7841
# Time taken for 1 epoch: 9.66 secs
#
# Epoch 30 Batch 0 Loss 1.1128
# Epoch 30 Batch 200 Loss 1.2913
# Saving checkpoint for epoch 30 at ./checkpoints/restaurant/ckpt-59
# Epoch 30: Loss 1.2957
# Dev loss: 1.7650 Dev Accuracy: 0.7926
# Time taken for 1 epoch: 9.59 secs
#
# Restore best epoch
#
# TEACHER:
# Test F1 Score: 0.5709
#
#               precision    recall  f1-score   support
#
#            0       0.28      0.56      0.38        57
#            1       0.87      0.78      0.82       355
#            2       0.68      0.58      0.63        36
#            3       0.63      0.55      0.59        22
#            4       0.49      0.55      0.52        31
#            5       0.73      0.38      0.50        29
#
#     accuracy                           0.70       530
#    macro avg       0.61      0.57      0.57       530
# weighted avg       0.75      0.70      0.72       530
#
# STUDENT:
# Test F1 Score: 0.5639
#
#               precision    recall  f1-score   support
#
#            0       0.28      0.56      0.37        57
#            1       0.87      0.78      0.82       355
#            2       0.68      0.58      0.63        36
#            3       0.67      0.55      0.60        22
#            4       0.50      0.52      0.51        31
#            5       0.67      0.34      0.45        29
#
#     accuracy                           0.69       530
#    macro avg       0.61      0.56      0.56       530
# weighted avg       0.75      0.69      0.71       530
